# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential, load_model
import pickle
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\ASUS\Desktop\Ai Project\ANN Classification\venv\Lib\site-packages\pandas\__init__.py:34
#      32 try:
#      33     # numpy compat
# ---> 34     from pandas.compat import (
#      35         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      36     )
#      37 except ImportError as _err:  # pragma: no cover
#
# File c:\Users\ASUS\Desktop\Ai Project\ANN Classification\venv\Lib\site-packages\pandas\compat\__init__.py:27
#      18 from pandas.compat._constants import (
#      19     CHAINED_WARNING_DISABLED,
#      20     IS64,
#    (...)     25     WASM,
#      26 )
# ---> 27 from pandas.compat.numpy import is_numpy_dev
#      28 from pandas.compat.pyarrow import (
#      29     HAS_PYARROW,
#      30     PYARROW_INSTALLED,
#    (...)     41     pa_version_under23p0,
#      42 )
# ...
